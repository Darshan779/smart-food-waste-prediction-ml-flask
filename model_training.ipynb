# %%
print("""
┌────────────────────────────────────────────────────────────┐
│     SMART FOOD WASTE PREDICTION SYSTEM (ML + Flask)        │
├────────────────────────────────────────────────────────────┤
│  INPUT                                                     │
│  • Day of Week                                             │
│  • Festival (0/1)                                          │
│  • Weather                                                 │
│  • Expected Customers                                      │
│  • Previous Day Consumption                                │
│  • Previous Week Same Day                                  │
├────────────────────────────────────────────────────────────┤
│  DATA PROCESSING                                           │
│  • Data Loading (Pandas)                                   │
│  • Data Cleaning                                           │
│  • Encoding (Label Encoding)                               │
│  • Feature Engineering                                     │
│    - Weekend Indicator                                     │
│    - Demand Trend                                          │
├────────────────────────────────────────────────────────────┤
│  MACHINE LEARNING                                          │
│  • Train-Test Split (80/20)                                │
│  • Model: Random Forest Regressor                          │
│  • Training                                                │
│  • Evaluation (MAE, RMSE)                                  │
├────────────────────────────────────────────────────────────┤
│  MODEL STORAGE                                             │
│  • Save Model (model.pkl using Pickle)                     │
├────────────────────────────────────────────────────────────┤
│  FLASK APPLICATION                                         │
│  • User Input Form                                         │
│  • Input Processing                                        │
│  • Model Prediction                                        │
│  • Display Output                                          │
├────────────────────────────────────────────────────────────┤
│  OUTPUT                                                    │
│  • Predicted Meals to Prepare                              │
│  Example: 430 meals                                        │
├────────────────────────────────────────────────────────────┤
│  BENEFITS                                                  │
│  • Reduce Food Waste                                       │
│  • Improve Planning                                        │
│  • Cost Efficiency                                         │
└────────────────────────────────────────────────────────────┘
""")
# Out:
# ┌────────────────────────────────────────────────────────────┐
# │     SMART FOOD WASTE PREDICTION SYSTEM (ML + Flask)        │
# ├────────────────────────────────────────────────────────────┤
# │  INPUT                                                     │
# │  • Day of Week                                             │
# │  • Festival (0/1)                                          │
# │  • Weather                                                 │
# │  • Expected Customers                                      │
# │  • Previous Day Consumption                                │
# │  • Previous Week Same Day                                  │
# ├────────────────────────────────────────────────────────────┤
# │  DATA PROCESSING                                           │
# │  • Data Loading (Pandas)                                   │
# │  • Data Cleaning                                           │
# │  • Encoding (Label Encoding)                               │
# │  • Feature Engineering                                     │
# │    - Weekend Indicator                                     │
# │    - Demand Trend                                          │
# ├────────────────────────────────────────────────────────────┤
# │  MACHINE LEARNING                                          │
# │  • Train-Test Split (80/20)                                │
# │  • Model: Random Forest Regressor                          │
# │  • Training                                                │
# │  • Evaluation (MAE, RMSE)                                  │
# ├────────────────────────────────────────────────────────────┤
# │  MODEL STORAGE                                             │
# │  • Save Model (model.pkl using Pickle)                     │
# ├────────────────────────────────────────────────────────────┤
# │  FLASK APPLICATION                                         │
# │  • User Input Form                                         │
# │  • Input Processing                                        │
# │  • Model Prediction                                        │
# │  • Display Output                                          │
# ├────────────────────────────────────────────────────────────┤
# │  OUTPUT                                                    │
# │  • Predicted Meals to Prepare                              │
# │  Example: 430 meals                                        │
# ├────────────────────────────────────────────────────────────┤
# │  BENEFITS                                                  │
# │  • Reduce Food Waste                                       │
# │  • Improve Planning                                        │
# │  • Cost Efficiency                                         │
# └────────────────────────────────────────────────────────────┘
